# %%
import pandas as pd
file = r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\nillens.csv'
df = pd.read_csv(file)
df = df[df['Description'].fillna('').str.strip() != ""]
df = df.dropna()
df
# Out:
#                                         Product        Variant   Price  \
# 0              Kaleidoscope Duvet + Pillowcases           King  7500.0
# 1              Kaleidoscope Duvet + Pillowcases          Queen  7500.0
# 2     Blue Paisley Duvet + Pillowcases (600 TC)           King  9200.0
# 3     Blue Paisley Duvet + Pillowcases (600 TC)          Queen  9200.0
# 4            White Duvet + Pillowcases (600 TC)           King  9200.0
# ...                                         ...            ...     ...
# 1444                   Lilac Short Sleeve Shirt          Small   455.0
# 1445                   Lilac Short Sleeve Shirt         Medium   455.0
# 1446                   Lilac Short Sleeve Shirt          Large   455.0
# 1447         Romana Linen Placemats  (Set of 2)  Default Title   450.0
# 1448         Meshmesh Cotton Napkins (Set of 2)  Default Title   200.0
#
#                                      Handle      Variant ID  Availability  \
# 0            kaleidoscope-duvet-pillowcases  40607487262768         False
# 1            kaleidoscope-duvet-pillowcases  40607487295536          True
# 2     blue-paisley-duvet-pillowcases-600-tc  39747113484336         False
# 3     blue-paisley-duvet-pillowcases-600-tc  39747113517104          True
# 4            white-duvet-pillowcases-600-tc  49782839902487          True
# ...                                     ...             ...           ...
# 1444               lilac-short-sleeve-shirt  49406503682327          True
# 1445               lilac-short-sleeve-shirt  49406503715095          True
# 1446               lilac-short-sleeve-shirt  49406503747863          True
# 1447        romana-linen-placemats-set-of-2  45492830241047          True
# 1448              meshmesh-napkins-set-of-2  51436881576215          True
#
#               SKU                                        Product URL  \
# 0     250003147.0  https://nillens.com/products/kaleidoscope-duve...
# 1     250003148.0  https://nillens.com/products/kaleidoscope-duve...
# 2     250002407.0  https://nillens.com/products/blue-paisley-duve...
# 3     250002408.0  https://nillens.com/products/blue-paisley-duve...
# 4     250002891.0  https://nillens.com/products/white-duvet-pillo...
# ...           ...                                                ...
# 1444  250005394.0  https://nillens.com/products/lilac-short-sleev...
# 1445  250005395.0  https://nillens.com/products/lilac-short-sleev...
# 1446  250005396.0  https://nillens.com/products/lilac-short-sleev...
# 1447  250004001.0  https://nillens.com/products/romana-linen-plac...
# 1448  250007464.0  https://nillens.com/products/meshmesh-napkins-...
#
#                   Scraped at  \
# 0     2026/02/02 11:24:26 AM
# 1     2026/02/02 11:24:26 AM
# 2     2026/02/02 11:24:27 AM
# 3     2026/02/02 11:24:27 AM
# 4     2026/02/02 11:24:29 AM
# ...                      ...
# 1444  2026/02/02 11:42:44 AM
# 1445  2026/02/02 11:42:44 AM
# 1446  2026/02/02 11:42:44 AM
# 1447  2026/02/02 11:42:45 AM
# 1448  2026/02/02 11:42:47 AM
#
#                                             Description
# 0     If you want a simple yet soft look this set is...
# 1     If you want a simple yet soft look this set is...
# 2     Designed for those of you who like a quieter b...
# 3     Designed for those of you who like a quieter b...
# 4     Designed for those of you who like a quieter b...
# ...                                                 ...
# 1444  \nThis short sleeve button down cotton shirt i...
# 1445  \nThis short sleeve button down cotton shirt i...
# 1446  \nThis short sleeve button down cotton shirt i...
# 1447  These placemats are designed to be mixed and m...
# 1448  These napkins are designed to be mixed and mat...
#
# [1438 rows x 10 columns]

# %%
import pandas as pd

# 1. Clean the 'Description' column BEFORE merging to remove new lines
df['Description'] = df['Description'].str.replace(r'\n|\r', ' ', regex=True)

# 2. Updated aggregation rules to create clean strings instead of Python lists
# We use ', '.join() to make "White, Cream" instead of "['White', 'Cream']"
aggregation_rules = {
    'Variant': lambda x: ', '.join(map(str, x.unique())), 
    'Variant ID': lambda x: ', '.join(map(str, x.unique())),
    'SKU': lambda x: ', '.join(map(str, x.unique())),
    'Handle': 'first',
    'Availability': 'first',
    'Product URL': 'first',
    'Scraped at': 'first'
}

# Group by the "Core" identity
df_merged = df.groupby(['Product', 'Description', 'Price'], as_index=False).agg(aggregation_rules)

# 3. FIX: Create the Hollistic Description correctly
# Use .astype(str) instead of str() to handle it row-by-row
df_merged['Hollistic Description'] = (
    df_merged['Product'] + 
    ' - ' + 
    df_merged['Variant'].astype(str) + 
    ": " + 
    df_merged["Description"]
)

# Reorder columns
columns_order = [
    'Product', 'Variant', 'Price', 'Handle', 'Variant ID', 
    'Availability', 'SKU', 'Product URL', 'Scraped at', 
    'Description', 'Hollistic Description'
]
df_merged = df_merged[columns_order]

# Save to CSV (index=False prevents that extra "0, 1, 2" column at the start)
df_merged.to_csv(r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\nillens_compact_view.csv', index=False)
df_merged
# Out:
#                                         Product  \
# 0                  Abstract Leaves Pyjama Pants
# 1                   Abstract Waves Pyjama Pants
# 2              Alphabet Patchwork Quilt (Multi)
# 3               Amber Bloom Warm Cotton Bottoms
# 4                Amber Bloom Warm Cotton Kimono
# ..                                          ...
# 740  Yellow Submarines Hooded Kids Towel (3-5Y)
# 741          Yellow/Blue Checkered Pyjama Pants
# 742                      Zazzy Violet Fez Dress
# 743                        Zebra Baby Sheet Set
# 744                     Zigzag Vibes Pareo Wrap
#
#                                     Variant   Price  \
# 0         Small, Medium, Large, Extra Large  1600.0
# 1    Small, Medium, Large, Extra Large, 2XL  1600.0
# 2                             Default Title  2900.0
# 3         Small, Medium, Large, Extra Large  1050.0
# 4                                  One Size  2300.0
# ..                                      ...     ...
# 740                           Default Title  1700.0
# 741       Small, Medium, Large, Extra Large  1500.0
# 742                               S/M, L/XL  3500.0
# 743                                     Cot  1520.0
# 744                                One Size  1400.0
#
#                                    Handle  \
# 0            abstract-leaves-pyjama-pants
# 1    copy-of-abstract-leaves-pyjama-pants
# 2                patchwork-elephant-quilt
# 3             amber-bloom-printed-bottoms
# 4               amber-bloom-viella-kimono
# ..                                    ...
# 740     yellow-submarines-baby-towel-larg
# 741    yellow-blue-checkered-pyjama-pants
# 742                zazzy-violet-fez-dress
# 743                  zebra-baby-sheet-set
# 744               zigzag-vibes-pareo-wrap
#
#                                             Variant ID  Availability  \
# 0    44717714899223, 44717714931991, 44717714964759...         False
# 1    47995280523543, 47995280556311, 47995280589079...         False
# 2                                       23058230280240         False
# 3    51401991094551, 51401991127319, 51401991160087...         False
# 4                                       51397007114519          True
# ..                                                 ...           ...
# 740                                     48870548242711          True
# 741  43648467337495, 43648467370263, 43648467403031...         False
# 742                     50307281682711, 50307281715479          True
# 743                                     31899680342064          True
# 744                                     50507149312279          True
#
#                                                    SKU  \
# 0    250003647.0, 250003648.0, 250003649.0, 2500036...
# 1    250005012.0, 250005013.0, 250005014.0, 2500050...
# 2                                          250003307.0
# 3    250007656.0, 250007657.0, 250007658.0, 2500076...
# 4                                          250007639.0
# ..                                                 ...
# 740                                        250004888.0
# 741  250003128.0, 250003129.0, 250003130.0, 2500031...
# 742                           250006906.0, 250006907.0
# 743                                        250003469.0
# 744                                        250007212.0
#
#                                            Product URL  \
# 0    https://nillens.com/products/abstract-leaves-p...
# 1    https://nillens.com/products/copy-of-abstract-...
# 2    https://nillens.com/products/patchwork-elephan...
# 3    https://nillens.com/products/amber-bloom-print...
# 4    https://nillens.com/products/amber-bloom-viell...
# ..                                                 ...
# 740  https://nillens.com/products/yellow-submarines...
# 741  https://nillens.com/products/yellow-blue-check...
# 742  https://nillens.com/products/zazzy-violet-fez-...
# 743  https://nillens.com/products/zebra-baby-sheet-set
# 744  https://nillens.com/products/zigzag-vibes-pare...
#
#                  Scraped at  \
# 0    2026/02/02 11:37:01 AM
# 1    2026/02/02 11:35:59 AM
# 2    2026/02/02 11:30:38 AM
# 3    2026/02/02 11:38:36 AM
# 4    2026/02/02 11:31:43 AM
# ..                      ...
# 740  2026/02/02 11:35:06 AM
# 741  2026/02/02 11:36:27 AM
# 742  2026/02/02 11:29:07 AM
# 743  2026/02/02 11:36:42 AM
# 744  2026/02/02 11:38:18 AM
#
#                                            Description  \
# 0    Our classic men's pyjama bottoms are perfect f...
# 1    Our classic men's pyjama bottoms are perfect f...
# 2    Our one-of-a-kind handmade patchwork quilts ca...
# 3     Our cozy summer pyjama bottoms are perfect to...
# 4    This printed cotton kimono is made from light-...
# ..                                                 ...
# 740  Wrap your little one after shower time with th...
# 741  Our cosy checkered winter pyjamas bottoms are ...
# 742  Relaxed and versatile, our Fez Dress has a loo...
# 743  Hand-embroidered zebra design paired with a so...
# 744  A must-have for beach days and poolside loungi...
#
#                                  Hollistic Description
# 0    Abstract Leaves Pyjama Pants - Small, Medium, ...
# 1    Abstract Waves Pyjama Pants - Small, Medium, L...
# 2    Alphabet Patchwork Quilt (Multi) - Default Tit...
# 3    Amber Bloom Warm Cotton Bottoms - Small, Mediu...
# 4    Amber Bloom Warm Cotton Kimono - One Size: Thi...
# ..                                                 ...
# 740  Yellow Submarines Hooded Kids Towel (3-5Y) - D...
# 741  Yellow/Blue Checkered Pyjama Pants - Small, Me...
# 742  Zazzy Violet Fez Dress - S/M, L/XL: Relaxed an...
# 743  Zebra Baby Sheet Set - Cot: Hand-embroidered z...
# 744  Zigzag Vibes Pareo Wrap - One Size: A must-hav...
#
# [745 rows x 11 columns]

# %%
'''
Products Table
'''
df_products = df_merged
df_products = df_products.drop(columns=['Variant', 'Price', 'Variant ID', 'Availability', 'SKU'])
df_products.to_csv(r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\nillens_products.csv', index=False)
df_products
# Out:
#                                         Product  \
# 0                  Abstract Leaves Pyjama Pants
# 1                   Abstract Waves Pyjama Pants
# 2              Alphabet Patchwork Quilt (Multi)
# 3               Amber Bloom Warm Cotton Bottoms
# 4                Amber Bloom Warm Cotton Kimono
# ..                                          ...
# 740  Yellow Submarines Hooded Kids Towel (3-5Y)
# 741          Yellow/Blue Checkered Pyjama Pants
# 742                      Zazzy Violet Fez Dress
# 743                        Zebra Baby Sheet Set
# 744                     Zigzag Vibes Pareo Wrap
#
#                                    Handle  \
# 0            abstract-leaves-pyjama-pants
# 1    copy-of-abstract-leaves-pyjama-pants
# 2                patchwork-elephant-quilt
# 3             amber-bloom-printed-bottoms
# 4               amber-bloom-viella-kimono
# ..                                    ...
# 740     yellow-submarines-baby-towel-larg
# 741    yellow-blue-checkered-pyjama-pants
# 742                zazzy-violet-fez-dress
# 743                  zebra-baby-sheet-set
# 744               zigzag-vibes-pareo-wrap
#
#                                            Product URL  \
# 0    https://nillens.com/products/abstract-leaves-p...
# 1    https://nillens.com/products/copy-of-abstract-...
# 2    https://nillens.com/products/patchwork-elephan...
# 3    https://nillens.com/products/amber-bloom-print...
# 4    https://nillens.com/products/amber-bloom-viell...
# ..                                                 ...
# 740  https://nillens.com/products/yellow-submarines...
# 741  https://nillens.com/products/yellow-blue-check...
# 742  https://nillens.com/products/zazzy-violet-fez-...
# 743  https://nillens.com/products/zebra-baby-sheet-set
# 744  https://nillens.com/products/zigzag-vibes-pare...
#
#                  Scraped at  \
# 0    2026/02/02 11:37:01 AM
# 1    2026/02/02 11:35:59 AM
# 2    2026/02/02 11:30:38 AM
# 3    2026/02/02 11:38:36 AM
# 4    2026/02/02 11:31:43 AM
# ..                      ...
# 740  2026/02/02 11:35:06 AM
# 741  2026/02/02 11:36:27 AM
# 742  2026/02/02 11:29:07 AM
# 743  2026/02/02 11:36:42 AM
# 744  2026/02/02 11:38:18 AM
#
#                                            Description  \
# 0    Our classic men's pyjama bottoms are perfect f...
# 1    Our classic men's pyjama bottoms are perfect f...
# 2    Our one-of-a-kind handmade patchwork quilts ca...
# 3     Our cozy summer pyjama bottoms are perfect to...
# 4    This printed cotton kimono is made from light-...
# ..                                                 ...
# 740  Wrap your little one after shower time with th...
# 741  Our cosy checkered winter pyjamas bottoms are ...
# 742  Relaxed and versatile, our Fez Dress has a loo...
# 743  Hand-embroidered zebra design paired with a so...
# 744  A must-have for beach days and poolside loungi...
#
#                                  Hollistic Description
# 0    Abstract Leaves Pyjama Pants - Small, Medium, ...
# 1    Abstract Waves Pyjama Pants - Small, Medium, L...
# 2    Alphabet Patchwork Quilt (Multi) - Default Tit...
# 3    Amber Bloom Warm Cotton Bottoms - Small, Mediu...
# 4    Amber Bloom Warm Cotton Kimono - One Size: Thi...
# ..                                                 ...
# 740  Yellow Submarines Hooded Kids Towel (3-5Y) - D...
# 741  Yellow/Blue Checkered Pyjama Pants - Small, Me...
# 742  Zazzy Violet Fez Dress - S/M, L/XL: Relaxed an...
# 743  Zebra Baby Sheet Set - Cot: Hand-embroidered z...
# 744  Zigzag Vibes Pareo Wrap - One Size: A must-hav...
#
# [745 rows x 6 columns]

# %%
'''
Variants Table
'''

df_variants = df
df_variants = df_variants.drop(columns=['Product', "Product URL", 'Description'])
cols_to_move = ['Variant ID', 'Handle', 'Variant', 'Price', 'SKU', 'Scraped at']

# Get the list of all other columns that aren't in the "move" list
remaining_cols = [c for c in df_variants.columns if c not in cols_to_move]

# Reorder with move-list first, then the rest
df_variants = df[cols_to_move + remaining_cols]
df_variants.to_csv(r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\nillens_variants.csv', index=False)
df_variants
# Out:
#           Variant ID                                 Handle        Variant  \
# 0     40607487262768         kaleidoscope-duvet-pillowcases           King
# 1     40607487295536         kaleidoscope-duvet-pillowcases          Queen
# 2     39747113484336  blue-paisley-duvet-pillowcases-600-tc           King
# 3     39747113517104  blue-paisley-duvet-pillowcases-600-tc          Queen
# 4     49782839902487         white-duvet-pillowcases-600-tc           King
# ...              ...                                    ...            ...
# 1444  49406503682327               lilac-short-sleeve-shirt          Small
# 1445  49406503715095               lilac-short-sleeve-shirt         Medium
# 1446  49406503747863               lilac-short-sleeve-shirt          Large
# 1447  45492830241047        romana-linen-placemats-set-of-2  Default Title
# 1448  51436881576215              meshmesh-napkins-set-of-2  Default Title
#
#        Price          SKU              Scraped at  Availability
# 0     7500.0  250003147.0  2026/02/02 11:24:26 AM         False
# 1     7500.0  250003148.0  2026/02/02 11:24:26 AM          True
# 2     9200.0  250002407.0  2026/02/02 11:24:27 AM         False
# 3     9200.0  250002408.0  2026/02/02 11:24:27 AM          True
# 4     9200.0  250002891.0  2026/02/02 11:24:29 AM          True
# ...      ...          ...                     ...           ...
# 1444   455.0  250005394.0  2026/02/02 11:42:44 AM          True
# 1445   455.0  250005395.0  2026/02/02 11:42:44 AM          True
# 1446   455.0  250005396.0  2026/02/02 11:42:44 AM          True
# 1447   450.0  250004001.0  2026/02/02 11:42:45 AM          True
# 1448   200.0  250007464.0  2026/02/02 11:42:47 AM          True
#
# [1438 rows x 7 columns]
