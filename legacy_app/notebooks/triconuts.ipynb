# %%
import pandas as pd
file = r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\output\Triconuts\triconuts.csv'
df = pd.read_csv(file)
df = df.drop(columns=['Weight'])
df = df.dropna(subset=['Description'])
df
# Out:
#                                Product                            Handle  \
# 0                 Ballerina Dreams Set            ballerina-dreams-set-1
# 1                              Cat Toy                   cat-toy-no-name
# 2     Blue Velvet Blanket (Super Soft)    blue-velvet-blanket-super-soft
# 3                 Beige Girl Bunny Toy                  girl-bunny-toy-2
# 4            Dinosaur Toy (Extra Soft)           dinosaur-toy-extra-soft
# ..                                 ...                               ...
# 93                White Girl Bunny Toy                    girl-bunny-toy
# 94      Winter Blue Scarf (EXTRA SOFT)      winter-blue-scarf-extra-soft
# 95                 White Boy Bunny Toy                     boy-bunny-toy
# 96  Yellow Velvet Blanket (Super Soft)  yellow-velvet-blanket-super-soft
# 97   White Velvet Blanket (Super Soft)   white-velvet-blanket-super-soft
#
#      Price  SKU  Availability  Variant Title      Variant ID  \
# 0   1859.0  NaN          True  Default Title  51058187436330
# 1    557.0  NaN         False  Default Title  47843545121066
# 2   1259.0  NaN          True  Default Title  51012227006762
# 3    499.0  NaN          True  Default Title  44188819292458
# 4    879.0  NaN          True  Default Title  49933380845866
# ..     ...  ...           ...            ...             ...
# 93   499.0  NaN          True  Default Title  44188791144746
# 94   539.0  NaN          True  Default Title  51039242780970
# 95   499.0  NaN          True  Default Title  44188844785962
# 96  1259.0  NaN          True  Default Title  51012246372650
# 97  1259.0  NaN          True  Default Title  51012290117930
#
#    Inventory Management                                        Product URL  \
# 0               shopify  https://www.triconuts.com//products/ballerina-...
# 1               shopify  https://www.triconuts.com//products/cat-toy-no...
# 2               shopify  https://www.triconuts.com//products/blue-velve...
# 3               shopify  https://www.triconuts.com//products/girl-bunny...
# 4               shopify  https://www.triconuts.com//products/dinosaur-t...
# ..                  ...                                                ...
# 93              shopify  https://www.triconuts.com//products/girl-bunny...
# 94              shopify  https://www.triconuts.com//products/winter-blu...
# 95              shopify  https://www.triconuts.com//products/boy-bunny-toy
# 96              shopify  https://www.triconuts.com//products/yellow-vel...
# 97              shopify  https://www.triconuts.com//products/white-velv...
#
#                 Scraped at                                        Description
# 0   2026/02/22 02:05:08 PM  Ballerina Dreams Set 🩰 A dreamy handmade gift ...
# 1   2026/02/22 02:05:09 PM  Hand-crocheted amigurumi cat plush toy in ligh...
# 2   2026/02/22 02:05:09 PM  Designed and handmade in Egypt For customized ...
# 3   2026/02/22 02:05:10 PM  Handmade 25 cm crochet bunny – the perfect sof...
# 4   2026/02/22 02:05:11 PM  100% handcrafted Safe for babies & kids Materi...
# ..                     ...                                                ...
# 93  2026/02/22 02:06:29 PM  Soft handmade crochet bunny, 25 cm tall — perf...
# 94  2026/02/22 02:06:30 PM  Soft Knit Baby Scarf – Cozy & Cute Winter Esse...
# 95  2026/02/22 02:06:31 PM  Handmade 25 cm crochet bunny with a blue bow t...
# 96  2026/02/22 02:06:32 PM  Designed and handmade in Egypt For customized ...
# 97  2026/02/22 02:06:33 PM  Designed and handmade in Egypt For customized ...
#
# [90 rows x 11 columns]

# %%
import pandas as pd

# 1. Clean the 'Description' column BEFORE merging to remove new lines
df['Description'] = df['Description'].str.replace(r'\n|\r', ' ', regex=True)

# 2. Updated aggregation rules to create clean strings instead of Python lists
# We use ', '.join() to make "White, Cream" instead of "['White', 'Cream']"
aggregation_rules = {
    # 'Title': lambda x: ', '.join(map(str, x.unique())),
    # 'Variant': lambda x: ', '.join(map(str, x.unique())), 
    'Variant ID': lambda x: ', '.join(map(str, x.unique())),
    'SKU': lambda x: ', '.join(map(str, x.unique())),
    # 'Size': lambda x: ', '.join(map(str, x.unique())),
    'Inventory Management': 'first',
    'Handle': 'first',
    'Availability': 'first',
    'Product URL': 'first',
    'Scraped at': 'first'
}

# Group by the "Core" identity
df_merged = df.groupby(['Product', 'Description', 'Price'], as_index=False).agg(aggregation_rules)

# 3. FIX: Create the Hollistic Description correctly
# Use .astype(str) instead of str() to handle it row-by-row
df_merged['Hollistic Description'] = (
    df_merged['Product'] + 
    # ' - ' + 
    # df_merged['Variant'].astype(str) + 
    ": " + 
    df_merged["Description"]
)

# Save to CSV (index=False prevents that extra "0, 1, 2" column at the start)
print(df_merged.columns)
df_merged.to_csv(r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\output\Triconuts\triconuts_compact.csv', index=False)
df_merged
# Out:
# Index(['Product', 'Description', 'Price', 'Variant ID', 'SKU',
#        'Inventory Management', 'Handle', 'Availability', 'Product URL',
#        'Scraped at', 'Hollistic Description'],
#       dtype='object')
#                                Product  \
# 0                 Baby Boy Besties Set
# 1                           Bakar Doll
# 2                 Ballerina Dreams Set
# 3                        Ballerina Toy
# 4                  Beige Boy Bunny Toy
# ..                                 ...
# 71                      Xmas Gift Card
# 72                      Xmas Gift Card
# 73                      Xmas Gift Card
# 74              Xmas Special Packaging
# 75  Yellow Velvet Blanket (Super Soft)
#
#                                           Description   Price      Variant ID  \
# 0   Baby Boy Besties Set The Baby Boy Besties Set ...   969.0  51058266997034
# 1   Meet our handcrafted Bakar Toy – a premium cro...  1199.0  51164360278314
# 2   Ballerina Dreams Set 🩰 A dreamy handmade gift ...  1859.0  51058187436330
# 3   Adorable handmade crocheted ballerina doll, 27...   599.0  49974051635498
# 4   Handmade 25 cm crochet bunny with a blue bow t...   499.0  44188834431274
# ..                                                ...     ...             ...
# 71  🎁Triconuts Gift Card Give the gift of choice! ...   250.0  50900945436970
# 72  🎁Triconuts Gift Card Give the gift of choice! ...   500.0  50900945469738
# 73  🎁Triconuts Gift Card Give the gift of choice! ...  1000.0  50900945502506
# 74  Want to get your order in a cute xmas package?...    50.0  50904546509098
# 75  Designed and handmade in Egypt For customized ...  1259.0  51012246372650
#
#     SKU Inventory Management                            Handle  Availability  \
# 0   nan              shopify            baby-boy-besties-set-1          True
# 1   nan              shopify                         bakar-toy          True
# 2   nan              shopify            ballerina-dreams-set-1          True
# 3   nan              shopify                     ballerina-toy          True
# 4   nan              shopify                   boy-bunny-toy-2          True
# ..  ...                  ...                               ...           ...
# 71  nan                 None                    xmas-gift-card          True
# 72  nan                 None                    xmas-gift-card          True
# 73  nan                 None                    xmas-gift-card          True
# 74  nan                 None              xmas-special-package          True
# 75  nan              shopify  yellow-velvet-blanket-super-soft          True
#
#                                           Product URL              Scraped at  \
# 0   https://www.triconuts.com//products/baby-boy-b...  2026/02/22 02:05:21 PM
# 1       https://www.triconuts.com//products/bakar-toy  2026/02/22 02:05:31 PM
# 2   https://www.triconuts.com//products/ballerina-...  2026/02/22 02:05:08 PM
# 3   https://www.triconuts.com//products/ballerina-toy  2026/02/22 02:05:20 PM
# 4   https://www.triconuts.com//products/boy-bunny-...  2026/02/22 02:05:29 PM
# ..                                                ...                     ...
# 71  https://www.triconuts.com//products/xmas-gift-...  2026/02/22 02:06:28 PM
# 72  https://www.triconuts.com//products/xmas-gift-...  2026/02/22 02:06:28 PM
# 73  https://www.triconuts.com//products/xmas-gift-...  2026/02/22 02:06:28 PM
# 74  https://www.triconuts.com//products/xmas-speci...  2026/02/22 02:06:25 PM
# 75  https://www.triconuts.com//products/yellow-vel...  2026/02/22 02:06:32 PM
#
#                                 Hollistic Description
# 0   Baby Boy Besties Set: Baby Boy Besties Set The...
# 1   Bakar Doll: Meet our handcrafted Bakar Toy – a...
# 2   Ballerina Dreams Set: Ballerina Dreams Set 🩰 A...
# 3   Ballerina Toy: Adorable handmade crocheted bal...
# 4   Beige Boy Bunny Toy: Handmade 25 cm crochet bu...
# ..                                                ...
# 71  Xmas Gift Card: 🎁Triconuts Gift Card Give the ...
# 72  Xmas Gift Card: 🎁Triconuts Gift Card Give the ...
# 73  Xmas Gift Card: 🎁Triconuts Gift Card Give the ...
# 74  Xmas Special Packaging: Want to get your order...
# 75  Yellow Velvet Blanket (Super Soft): Designed a...
#
# [76 rows x 11 columns]

# %%
'''
Products Table
'''
df_products = df_merged
df_products = df_products.drop(columns=['Variant ID', 'Availability'])

# Split by comma and strip whitespace from each element
# 1. First, split the strings into lists (if you haven't already)
df_products['SKUs'] = df_products['SKU'].str.split(',')

# 2. Grab the first element of each list and strip whitespace
df_products['SKU'] = df_products['SKUs'].str[0].str.strip()
# 1. Clean up the decimals and whitespace within the lists first
# This removes '.0' and extra spaces from every item in every list
df_products['SKUs'] = df_products['SKUs'].apply(lambda x: [i.replace('.0', '').strip() for i in x])

# 2. Join the list elements into a single string separated by a space
df_products['SKUs'] = df_products['SKUs'].str.join(' ')

df_products.to_csv(r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\output\Triconuts\triconuts_products.csv', index=False)
df_products.columns
# Out:
# Index(['Product', 'Description', 'Price', 'SKU', 'Inventory Management',
#        'Handle', 'Product URL', 'Scraped at', 'Hollistic Description', 'SKUs'],
#       dtype='object')
