# %%
import pandas as pd
file = r'C:\Users\moham\WebScraping\legacy_app\output\ninos_kids\ninos.csv'
df = pd.read_csv(file)
df = df.rename({'Variant Title': 'Variant'}, axis='columns')
df
# Out:
#                                      Product  \
# 0                1.88m x 71cm Fashion Lounge
# 1                1.88m x 71cm Fashion Lounge
# 2     1.83m x H38cm Fill 'N Fun Odyssey Pool
# 3                 1.65m Splash Pad SpiderMan
# 4                  1.07m Geometric Swim Ring
# ...                                      ...
# 9724                       كوب مانع للتسرب+6
# 9725             ملعقة سيليكون بيد ربر الوان
# 9726                  مقص كانبول بجراب الوان
# 9727                             مقص لافروتا
# 9728          وسائد ثدي ترو القطنية  30 قطعة
#
#                                                  Handle  Price  \
# 0                           1-88m-x-71cm-fashion-lounge  399.0
# 1                         1-88m-x-71cm-fashion-lounge-2  399.0
# 2                 1-83m-x-h38cm-fill-n-fun-odyssey-pool  849.0
# 3                            1-65m-splash-pad-spiderman  999.0
# 4                             1-07m-geometric-swim-ring  385.0
# ...                                                 ...    ...
# 9724  %D9%83%D9%88%D8%A8-%D9%85%D8%A7%D9%86%D8%B9-%D...  350.0
# 9725  %D9%85%D9%84%D8%B9%D9%82%D8%A9-%D8%B3%D9%8A%D9...  225.0
# 9726  %D9%85%D9%82%D8%B5-%D9%83%D8%A7%D9%86%D8%A8%D9...  225.0
# 9727  %D9%85%D9%82%D8%B5-%D9%84%D8%A7%D9%81%D8%B1%D9...   95.0
# 9728  %D9%88%D8%B3%D8%A7%D8%A6%D8%AF-%D8%AB%D8%AF%D9...  190.0
#
#                     SKU  Availability           Variant      Variant ID  \
# 0     140214-S23-43040W         False      White / Free  41562102792401
# 1     140214-S23-43040F         False     Fuscia / Free  41562102857937
# 2      140214-S23-55030         False       Blue / Free  41562173898961
# 3      140214-S23-98792         False       Navy / Free  41562241237201
# 4     140214-S23-36228W         False      White / Free  41562079101137
# ...                 ...           ...               ...             ...
# 9724     414-S22-35/208          True       Blue / Free  42898370986193
# 9725     414-R23-21/488         False  Mix Color / Free  42445153075409
# 9726        414-R-2/809          True     Default Title  41026652242129
# 9727        414-R-22642          True     Default Title  41026615050449
# 9728    414-R23-18920TR          True  Mix Color / Free  41512961474769
#
#       Weight Inventory Management  \
# 0          0              shopify
# 1          0              shopify
# 2          0              shopify
# 3          0              shopify
# 4          0              shopify
# ...      ...                  ...
# 9724       0              shopify
# 9725       0              shopify
# 9726       0              shopify
# 9727       0              shopify
# 9728       0              shopify
#
#                                             Product URL  \
# 0     https://www.ninoskids.com/en/products/1-88m-x-...
# 1     https://www.ninoskids.com/en/products/1-88m-x-...
# 2     https://www.ninoskids.com/en/products/1-83m-x-...
# 3     https://www.ninoskids.com/en/products/1-65m-sp...
# 4     https://www.ninoskids.com/en/products/1-07m-ge...
# ...                                                 ...
# 9724  https://www.ninoskids.com/en/products/%D9%83%D...
# 9725  https://www.ninoskids.com/en/products/%D9%85%D...
# 9726  https://www.ninoskids.com/en/products/%D9%85%D...
# 9727  https://www.ninoskids.com/en/products/%D9%85%D...
# 9728  https://www.ninoskids.com/en/products/%D9%88%D...
#
#                   Scraped at  \
# 0     2026/02/23 02:05:58 PM
# 1     2026/02/23 02:05:59 PM
# 2     2026/02/23 02:06:00 PM
# 3     2026/02/23 02:06:01 PM
# 4     2026/02/23 02:06:02 PM
# ...                      ...
# 9724  2026/02/23 02:35:36 PM
# 9725  2026/02/23 02:35:38 PM
# 9726  2026/02/23 02:35:39 PM
# 9727  2026/02/23 02:35:40 PM
# 9728  2026/02/23 02:35:41 PM
#
#                                             Description
# 0     Introducing the ultimate summer essential - th...
# 1     Introducing the ultimate poolside accessory - ...
# 2     "Add a splash of fun to your backyard with our...
# 3     Introducing the ultimate summer accessory for ...
# 4     Add some geometric fun to your pool days with ...
# ...                                                 ...
# 9724  Introducing our leak-proof cup, a must-have fo...
# 9725                                                NaN
# 9726                                                NaN
# 9727                                                NaN
# 9728  Introducing the Tru Cotton Breast Pads, a must...
#
# [9729 rows x 12 columns]

# %%
import pandas as pd

# 1. Clean the 'Description' column BEFORE merging to remove new lines
df['Description'] = df['Description'].str.replace(r'\n|\r', ' ', regex=True)

# 2. Updated aggregation rules to create clean strings instead of Python lists
# We use ', '.join() to make "White, Cream" instead of "['White', 'Cream']"
aggregation_rules = {
    # 'Title': lambda x: ', '.join(map(str, x.unique())),
    'Variant': lambda x: ', '.join(map(str, x.unique())), 
    'Variant ID': lambda x: ', '.join(map(str, x.unique())),
    'SKU': lambda x: ', '.join(map(str, x.unique())),
    # 'Size': lambda x: ', '.join(map(str, x.unique())),
    'Inventory Management': 'first',
    'Handle': 'first',
    'Availability': 'first',
    'Product URL': 'first',
    'Scraped at': 'first'
}

# Group by the "Core" identity
df_merged = df.groupby(['Product', 'Description', 'Price'], as_index=False).agg(aggregation_rules)

# 3. FIX: Create the Hollistic Description correctly
# Use .astype(str) instead of str() to handle it row-by-row
df_merged['Hollistic Description'] = (
    df_merged['Product'] + 
    ' - ' + 
    df_merged['Variant'].astype(str) + 
    ": " + 
    df_merged["Description"]
)

# Save to CSV (index=False prevents that extra "0, 1, 2" column at the start)
print(df_merged.columns)
df_merged.to_csv(r'C:\Users\moham\WebScraping\legacy_app\output\ninos_kids\ninos_compact.csv', index=False)
df_merged
# Out:
# Index(['Product', 'Description', 'Price', 'Variant', 'Variant ID', 'SKU',
#        'Inventory Management', 'Handle', 'Availability', 'Product URL',
#        'Scraped at', 'Hollistic Description'],
#       dtype='object')
#                                           Product  \
# 0                       1.07m Geometric Swim Ring
# 1       1.19m x 79cm Happy Crustacean Junior Raft
# 2                        1.1L Lunch Box with Tray
# 3                   1.22m x H25cm Coral Kids Pool
# 4            1.34m x 1.42m Fantasy Dragon Ride On
# ...                                           ...
# 1775                            كوب مانع للتسرب+6
# 1776                            كوب مانع للتسرب+6
# 1777                                    ماصة طعام
# 1778  ماصة فواكه سيليكون بيد طويلة بالغيار من ترو
# 1779               وسائد ثدي ترو القطنية  30 قطعة
#
#                                             Description  Price  \
# 0     Add some geometric fun to your pool days with ...  385.0
# 1     Get ready for a splashing good time with our H...  479.0
# 2     Our 3-piece lunch set is an essential for busy...  147.0
# 3     Introduce your little ones to the joy of swimm...  399.0
# 4     Get ready for an epic adventure with our 1.34m...  799.0
# ...                                                 ...    ...
# 1775  Introducing our leak-proof cup, a must-have fo...  350.0
# 1776  Introducing our leak-proof cup, a must-have fo...  400.0
# 1777  -3 YearsIntroduce your little one to the delic...  310.0
# 1778  Size Introducing the perfect solution for feed...  235.0
# 1779  Introducing the Tru Cotton Breast Pads, a must...  190.0
#
#                Variant      Variant ID                SKU  \
# 0         White / Free  41562079101137  140214-S23-36228W
# 1     Turquiose / Free  41561373409489   140214-S23-34009
# 2         Black / 1.1L  42671366209745    363137-NOS-6441
# 3          Blue / Free  41562104365265   140214-S23-51009
# 4         Green / Free  41562101973201   140214-S23-41476
# ...                ...             ...                ...
# 1775       Blue / Free  42898370986193     414-S22-35/208
# 1776       Pink / Free  42898370953425     414-S22-35/208
# 1777                6M  42257066918097        435-R21-207
# 1778  Mix Color / Free  41512960524497  414-R23-2022017TR
# 1779  Mix Color / Free  41512961474769    414-R23-18920TR
#
#      Inventory Management                                             Handle  \
# 0                 shopify                          1-07m-geometric-swim-ring
# 1                 shopify          1-19m-x-79cm-happy-crustacean-junior-raft
# 2                 shopify                         1-1l-lunch-box-with-tray-2
# 3                 shopify                      1-22m-x-h25cm-coral-kids-pool
# 4                 shopify               1-34m-x-1-42m-fantasy-dragon-ride-on
# ...                   ...                                                ...
# 1775              shopify  %D9%83%D9%88%D8%A8-%D9%85%D8%A7%D9%86%D8%B9-%D...
# 1776              shopify  %D9%83%D9%88%D8%A8-%D9%85%D8%A7%D9%86%D8%B9-%D...
# 1777              shopify  %D9%85%D8%A7%D8%B5%D8%A9-%D8%B7%D8%B9%D8%A7%D9%85
# 1778              shopify  %D9%85%D8%A7%D8%B5%D8%A9-%D9%81%D9%88%D8%A7%D9...
# 1779              shopify  %D9%88%D8%B3%D8%A7%D8%A6%D8%AF-%D8%AB%D8%AF%D9...
#
#       Availability                                        Product URL  \
# 0            False  https://www.ninoskids.com/en/products/1-07m-ge...
# 1            False  https://www.ninoskids.com/en/products/1-19m-x-...
# 2            False  https://www.ninoskids.com/en/products/1-1l-lun...
# 3            False  https://www.ninoskids.com/en/products/1-22m-x-...
# 4            False  https://www.ninoskids.com/en/products/1-34m-x-...
# ...            ...                                                ...
# 1775          True  https://www.ninoskids.com/en/products/%D9%83%D...
# 1776          True  https://www.ninoskids.com/en/products/%D9%83%D...
# 1777          True  https://www.ninoskids.com/en/products/%D9%85%D...
# 1778          True  https://www.ninoskids.com/en/products/%D9%85%D...
# 1779          True  https://www.ninoskids.com/en/products/%D9%88%D...
#
#                   Scraped at  \
# 0     2026/02/23 02:06:02 PM
# 1     2026/02/23 02:06:04 PM
# 2     2026/02/23 02:06:07 PM
# 3     2026/02/23 02:06:06 PM
# 4     2026/02/23 02:06:05 PM
# ...                      ...
# 1775  2026/02/23 02:35:36 PM
# 1776  2026/02/23 02:35:36 PM
# 1777  2026/02/23 02:35:32 PM
# 1778  2026/02/23 02:35:30 PM
# 1779  2026/02/23 02:35:41 PM
#
#                                   Hollistic Description
# 0     1.07m Geometric Swim Ring - White / Free: Add ...
# 1     1.19m x 79cm Happy Crustacean Junior Raft - Tu...
# 2     1.1L Lunch Box with Tray - Black / 1.1L: Our 3...
# 3     1.22m x H25cm Coral Kids Pool - Blue / Free: I...
# 4     1.34m x 1.42m Fantasy Dragon Ride On - Green /...
# ...                                                 ...
# 1775  كوب مانع للتسرب+6 - Blue / Free: Introducing o...
# 1776  كوب مانع للتسرب+6 - Pink / Free: Introducing o...
# 1777  ماصة طعام - 6M: -3 YearsIntroduce your little ...
# 1778  ماصة فواكه سيليكون بيد طويلة بالغيار من ترو - ...
# 1779  وسائد ثدي ترو القطنية  30 قطعة - Mix Color / F...
#
# [1780 rows x 12 columns]

# %%
'''
Products Table
'''
df_products = df_merged
df_products = df_products.drop(columns=['Variant ID', 'Availability'])

# Split by comma and strip whitespace from each element
# 1. First, split the strings into lists (if you haven't already)
df_products['SKUs'] = df_products['SKU'].str.split(',')

# 2. Grab the first element of each list and strip whitespace
df_products['SKU'] = df_products['SKUs'].str[0].str.strip()
# 1. Clean up the decimals and whitespace within the lists first
# This removes '.0' and extra spaces from every item in every list
df_products['SKUs'] = df_products['SKUs'].apply(lambda x: [i.replace('.0', '').strip() for i in x])

# 2. Join the list elements into a single string separated by a space
df_products['SKUs'] = df_products['SKUs'].str.join(' ')

df_products.to_csv(r'C:\Users\moham\WebScraping\legacy_app\output\ninos_kids\ninos_products.csv', index=False)
df_products.columns
# Out:
# Index(['Product', 'Description', 'Price', 'Variant', 'SKU',
#        'Inventory Management', 'Handle', 'Product URL', 'Scraped at',
#        'Hollistic Description', 'SKUs'],
#       dtype='object')
