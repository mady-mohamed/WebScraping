# %%
import pandas as pd

pd.read_csv(r"C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\output\all\all_products.csv")
# Out:
#      Unnamed: 0                            Product  \
# 0             0    Astronauts - Swaddle Towel sets
# 1             1  Baby animals - Swaddle Towel sets
# 2             2              Ballerina - Bath robe
# 3             3              Ballerina - Duvet set
# 4             4                Boxer Underwear bag
# ..          ...                                ...
# 760         760             Zazzy Violet Fez Dress
# 761         761               Zebra Baby Sheet Set
# 762         762            Zigzag Vibes Pareo Wrap
# 763         763                           Bath mat
# 764         764                          Half face
#
#                               Handle  \
# 0      astronauts-swaddle-towel-sets
# 1    baby-animals-swaddle-towel-sets
# 2                ballerina-bath-robe
# 3                ballerina-duvet-set
# 4                boxer-underwear-bag
# ..                               ...
# 760           zazzy-violet-fez-dress
# 761             zebra-baby-sheet-set
# ...
