# [5952 rows x 12 columns]

# %%
import pandas as pd

# 1. Clean the 'Description' column BEFORE merging to remove new lines
df['Description'] = df['Description'].str.replace(r'\n|\r', ' ', regex=True)

# 2. Updated aggregation rules to create clean strings instead of Python lists
# We use ', '.join() to make "White, Cream" instead of "['White', 'Cream']"
aggregation_rules = {
    # 'Title': lambda x: ', '.join(map(str, x.unique())),
    'Variant': lambda x: ', '.join(map(str, x.unique())), 
    'Variant ID': lambda x: ', '.join(map(str, x.unique())),
    'SKU': lambda x: ', '.join(map(str, x.unique())),
    # 'Size': lambda x: ', '.join(map(str, x.unique())),
    'Inventory Management': 'first',
    'Handle': 'first',
    'Availability': 'first',
    'Product URL': 'first',
    'Scraped at': 'first'
}

# Group by the "Core" identity
df_merged = df.groupby(['Product', 'Description', 'Price'], as_index=False).agg(aggregation_rules)

# 3. FIX: Create the Hollistic Description correctly
# Use .astype(str) instead of str() to handle it row-by-row
df_merged['Hollistic Description'] = (
    df_merged['Product'] + 
    ' - ' + 
    df_merged['Variant'].astype(str) + 
    ": " + 
    df_merged["Description"]
)

# Save to CSV (index=False prevents that extra "0, 1, 2" column at the start)
print(df_merged.columns)
df_merged.to_csv(r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\output\Lovely_land\lovely_land_compact.csv', index=False)
df_merged
# Out:
# Index(['Product', 'Description', 'Price', 'Variant', 'Variant ID', 'SKU',
#        'Inventory Management', 'Handle', 'Availability', 'Product URL',
#        'Scraped at', 'Hollistic Description'],
#       dtype='object')
#                                Product  \
# 0                  Anti-dandruff Cream
# 1                Anti-dandruff Shampoo
# 2                BABY CARRIER UNI BABY
# 3     Baby  Bodysuit Pack Of 3 6213-74
# 4                Baby Bed All On Board
# ...                                ...
# 1297                    Wide Leg Pants
# 1298                    Wide Leg Pants
# 1299                    Wide Leg Pants
# 1300                    Wide Leg Short
# 1301          moringa kids conditioner
#
#                                             Description   Price  \
# 0     High Quality Cotton Blend and comfy Pandolen A...   140.0
# 1     High Quality Cotton Blend and comfy Penduline ...   160.0
# 2     High Quality Carrier Uni Baby10330107• 4-in 1 ...   750.0
# 3     High Premium Organic Egyptian CottonPrintedLon...   350.0
# 4     High Quality Bed All On Board 10530103Waterpro...  1725.0
# ...                                                 ...     ...
# 1297  High Quality Cotton Blend and comfy Wide Leg P...   490.0
# 1298  High Quality Cotton Blend and comfy Wide Leg P...   412.5
# 1299  High Quality Cotton Blend and comfy Wide Leg P...   397.5
# 1300  High Quality Cotton Blend and comfy Wide Leg S...   382.5
# 1301  High Quality Cotton Blend and comfy Penduline ...   175.0
#
#                                                 Variant  \
# 0                                         Default Title
# 1                                         Default Title
# 2                                                Purple
# 3     Olive * Rose * Printed Olive / 0 - 3 Months, O...
# 4                                                Fushia
# ...                                                 ...
# 1297  Black / 3 - 4 Years, Black / 5 - 6 Years, Blac...
# 1298  Black / 3 - 4 Years, Black / 5 - 6 Years, Blac...
# 1299  Kaki / 3 - 4 Years, Kaki / 5 - 6 Years, Kaki /...
# 1300  Blue / 3 - 4 Years, Blue / 5 - 6 Years, Blue /...
# 1301                                      Default Title
#
#                                              Variant ID  \
# 0                                        46095087763701
# 1                                        46095087239413
# 2                                        42532811178229
# 3     45904598827253, 45904598860021, 45904598892789...
# 4                                        44009535144181
# ...                                                 ...
# 1297  46615983292661, 46615983325429, 46615983358197...
# 1298  46615965892853, 46615965925621, 46615965958389...
# 1299  46615965434101, 46615965466869, 46615965499637...
# 1300  46615939875061, 46615939907829, 46615939940597...
# 1301                                     46095087927541
#
#                                                     SKU Inventory Management  \
# 0                                                137070              shopify
# 1                                                137069              shopify
# 2                                                 97367              shopify
# 3     1174621303, 1174621306, 1174621309, 1174621312...              shopify
# 4                                                132327              shopify
# ...                                                 ...                  ...
# 1297  3260101404, 3260101406, 3260101408, 3260101410...              shopify
# 1298  3261101404, 3261101406, 3261101408, 3261101410...              shopify
# 1299  3261102704, 3261102706, 3261102708, 3261102710...              shopify
# 1300  3262142004, 3262142006, 3262142008, 3262142010...              shopify
# 1301                                             137075              shopify
#
#         Handle  Availability                                Product URL  \
# 0       111709          True    https://junior-tex.com//products/111709
# 1       111389          True    https://junior-tex.com//products/111389
# 2     10330107          True  https://junior-tex.com//products/10330107
# 3      6213-74         False   https://junior-tex.com//products/6213-74
# 4     10530103          True  https://junior-tex.com//products/10530103
# ...        ...           ...                                        ...
# 1297   2601014          True   https://junior-tex.com//products/2601014
# 1298   2611014         False   https://junior-tex.com//products/2611014
# 1299   2611027          True   https://junior-tex.com//products/2611027
# 1300   2621420         False   https://junior-tex.com//products/2621420
# 1301    112720          True    https://junior-tex.com//products/112720
#
#                   Scraped at  \
# 0     2026/02/22 02:41:35 PM
# 1     2026/02/22 02:41:32 PM
# 2     2026/02/22 02:41:46 PM
# 3     2026/02/22 02:41:20 PM
# 4     2026/02/22 02:41:26 PM
# ...                      ...
# 1297  2026/02/22 03:02:36 PM
# 1298  2026/02/22 03:02:46 PM
# 1299  2026/02/22 03:03:16 PM
# 1300  2026/02/22 03:03:15 PM
# 1301  2026/02/22 02:51:32 PM
#
#                                   Hollistic Description
# 0     Anti-dandruff Cream - Default Title: High Qual...
# 1     Anti-dandruff Shampoo - Default Title: High Qu...
# 2     BABY CARRIER UNI BABY - Purple: High Quality C...
# 3     Baby  Bodysuit Pack Of 3 6213-74 - Olive * Ros...
# 4     Baby Bed All On Board - Fushia: High Quality B...
# ...                                                 ...
# 1297  Wide Leg Pants - Black / 3 - 4 Years, Black / ...
# 1298  Wide Leg Pants - Black / 3 - 4 Years, Black / ...
# 1299  Wide Leg Pants - Kaki / 3 - 4 Years, Kaki / 5 ...
# 1300  Wide Leg Short - Blue / 3 - 4 Years, Blue / 5 ...
# 1301  moringa kids conditioner - Default Title: High...
#
# [1302 rows x 12 columns]

# %%
'''
Products Table
'''
df_products = df_merged
df_products = df_products.drop(columns=['Variant ID', 'Availability'])

# Split by comma and strip whitespace from each element
# 1. First, split the strings into lists (if you haven't already)
df_products['SKUs'] = df_products['SKU'].str.split(',')

# 2. Grab the first element of each list and strip whitespace
df_products['SKU'] = df_products['SKUs'].str[0].str.strip()
# 1. Clean up the decimals and whitespace within the lists first
# This removes '.0' and extra spaces from every item in every list
df_products['SKUs'] = df_products['SKUs'].apply(lambda x: [i.replace('.0', '').strip() for i in x])

# 2. Join the list elements into a single string separated by a space
df_products['SKUs'] = df_products['SKUs'].str.join(' ')

df_products.to_csv(r'C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\output\Lovely_land\lovely_land_products.csv', index=False)
df_products.columns
# Out:
# Index(['Product', 'Description', 'Price', 'Variant', 'SKU',
#        'Inventory Management', 'Handle', 'Product URL', 'Scraped at',
#        'Hollistic Description', 'SKUs'],
#       dtype='object')
