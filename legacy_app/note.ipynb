# %%
# %pip install pandas
# Out:
# ...
#   Using cached pandas-2.3.3-cp310-cp310-win_amd64.whl (11.3 MB)
# ...
#   Using cached tzdata-2025.3-py2.py3-none-any.whl (348 kB)
# ...
#   Using cached numpy-2.2.6-cp310-cp310-win_amd64.whl (12.9 MB)
# ...
#   Using cached pytz-2025.2-py2.py3-none-any.whl (509 kB)
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.4; however, version 25.3 is available.
# You should consider upgrading via the 'c:\Users\moham\OneDrive\Desktop\WebScraping\.venv\Scripts\python.exe -m pip install --upgrade pip' command.

# %%
import pandas as pd

df = pd.read_csv('heba_variants.csv')
df
# Out:
#                                Product                     Variant   Price  \
# 0                    Atraction - Pouch          Grey / 14 L X 18 W   495.0
# 1                   Esprit - Towel Set                       White  1795.0
# 2                  Boxer Underwear bag         White / 60 L X 40 W   395.0
# 3    Baby animals - Swaddle Towel sets                       White   995.0
# 4    Baby animals - Swaddle Towel sets                       Cream   995.0
# ..                                 ...                         ...     ...
# 214                 Tennis - Bath robe  6 years to 8 years / White   945.0
# 215                   Trio - Sheet Set                King / White  6295.0
# 216                   Trio - Sheet Set               King / Silver  6295.0
# 217                   Trio - Towel Set                       White  1995.0
# 218                   Trio - Towel Set                      Silver  1995.0
#
# ...
