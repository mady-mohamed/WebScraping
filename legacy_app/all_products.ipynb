# %%
'''
All Products
'''
import pandas as pd

df_heba = pd.read_csv(r"C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\heba_products.csv")
df_nillens = pd.read_csv(r"C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\nillens_products.csv")
df_lilly = pd.read_csv(r"C:\Users\moham\OneDrive\Desktop\WebScraping\legacy_app\lilly_home_products.csv")

# %%
df_heba["Brand"] = "Heba Linens"
df_nillens["Brand"] = "Nillens"
df_lilly["Brand"] = "Lilly Home"
# print(f"Heba No. of Products {df_heba.shape[0]} \nLilly Home No. of Products: {df_lilly.shape[0]}")
# print(f"Nillens No. of Products: {df_nillens.shape[0]}")
# print(f"Total No. of Products: {df_heba.shape[0] + df_nillens.shape[0] + df_lilly.shape[0]}")
df_combined_products = pd.concat([df_heba, df_nillens, df_lilly], ignore_index=True)
df_combined_products
# Out:
#                                Product                           Handle  \
# 0      Astronauts - Swaddle Towel sets    astronauts-swaddle-towel-sets
# 1    Baby animals - Swaddle Towel sets  baby-animals-swaddle-towel-sets
# 2                Ballerina - Bath robe              ballerina-bath-robe
# 3                Ballerina - Bath robe              ballerina-bath-robe
# 4                Ballerina - Duvet set              ballerina-duvet-set
# ..                                 ...                              ...
# 792             Zazzy Violet Fez Dress           zazzy-violet-fez-dress
# 793               Zebra Baby Sheet Set             zebra-baby-sheet-set
# 794            Zigzag Vibes Pareo Wrap          zigzag-vibes-pareo-wrap
# 795                           Bath mat                         bath-mat
# 796                          Half face                        half-face
#
#                                            Product URL  \
# ...
